# %% [markdown]
# # Index
# * [Introduction](twp_00_Introduction.ipynb#Introduction)
#   * [Preface](twp_00_Introduction.ipynb#Preface)
#   * [Installation](twp_00_Introduction.ipynb#Installation)
# * [Development tools](twp_101_development_tools.ipynb#Development-tools)
#   * [IPython](twp_101_development_tools.ipynb#IPython)
#   * [Source code editors](twp_101_development_tools.ipynb#Source-code-editors)
#   * [Jupyter notebook](twp_101_development_tools.ipynb#Jupyter-notebook)
# * [Overview of python basics](twp_102_python_basics.ipynb#Overview-of-python-basics)
#   * [Working with modules](twp_102a_working_with_modules.ipynb#Working-with-modules)
# * [Visualizing data](twp_103_plotting.ipynb#Visualizing-data)
#   * [Visualization with matplotlib](twp_103_plotting.ipynb#Visualization-with-matplotlib)
#   * [Plotting with Pandas](twp_103_plotting.ipynb#Plotting-with-Pandas)
#   * [Bokeh plots](twp_103_plotting.ipynb#Bokeh-plots)
#   * [TWP plotting class](twp_103_plotting.ipynb#TWP-plotting-class)
# * [Simulating leveraged etfs](twp_200_Leveraged_etfs.ipynb#Simulating-leveraged-etfs)
#   * [How about 3x leverage?](twp_200_Leveraged_etfs.ipynb#How-about-3x-leverage?)
# * [Day of week seasonality of SPY](twp_201_Day_seasonality.ipynb#Day-of-week-seasonality-of-SPY)
#   * [Get the data](twp_201_Day_seasonality.ipynb#Get-the-data)
#   * [Working with dates and times](twp_201_Day_seasonality.ipynb#Working-with-dates-and-times)
#   * [Analyse weekday seasonality](twp_201_Day_seasonality.ipynb#Analyse-weekday-seasonality)
# * [Working with csv files](twp_202_Reading_csv_files.ipynb#Working-with-csv-files)
#   * [Reading csv](twp_202_Reading_csv_files.ipynb#Reading-csv)
#   * [Writing csv files](twp_202_Reading_csv_files.ipynb#Writing-csv-files)
# * [Building a stock price database](twp_203_Building_a_stock_database.ipynb#Building-a-stock-price-database)
#   * [Download historic data](twp_203_Building_a_stock_database.ipynb#Download-historic-data)
#   * [Multi-index](twp_203_Building_a_stock_database.ipynb#Multi-index)
#   * [Save data to file](twp_203_Building_a_stock_database.ipynb#Save-data-to-file)
#   * [Load data from file](twp_203_Building_a_stock_database.ipynb#Load-data-from-file)
# * [Performance metrics](twp_301_Performance_metrics.ipynb#Performance-metrics)
#   * [Sharpe ratio](twp_301_Performance_metrics.ipynb#Sharpe-ratio)
#   * [Drawdown](twp_301_Performance_metrics.ipynb#Drawdown)
#   * [Profit ratio](twp_301_Performance_metrics.ipynb#Profit-ratio)
# * [Backtesting with TWP backtesting module](twp_302b_backtesting.ipynb#Backtesting-with-TWP-backtesting-module)
#   * [Test on real price data](twp_302b_backtesting.ipynb#Test-on-real-price-data)
#   * [Walk-forward moving averages strategy](twp_302c_backtesting-moving_averages.ipynb#Walk-forward-moving-averages-strategy)
# * [Moving averages crossover strategy](twp_302_moving_averages_strat.ipynb#Moving-averages-crossover-strategy)
#   * [Divide dataset](twp_302_moving_averages_strat.ipynb#Divide-dataset)
#   * [Develop strategy](twp_302_moving_averages_strat.ipynb#Develop-strategy)
#   * [Make a parameter scan](twp_302_moving_averages_strat.ipynb#Make-a-parameter-scan)
#   * [Conclusion](twp_302_moving_averages_strat.ipynb#Conclusion)
# * [Permanent portfolio](twp_303_permanent_portfolio.ipynb#Permanent-portfolio)
#   * [Get price data](twp_303_permanent_portfolio.ipynb#Get-price-data)
#   * [Simulate portfolio](twp_303_permanent_portfolio.ipynb#Simulate-portfolio)
#   * [Conclusion](twp_303_permanent_portfolio.ipynb#Conclusion)
# * [XLP strategy](twp_304_xlp_strategy.ipynb#XLP-strategy)
#   * [Rewrite strategy to a single function](twp_304_xlp_strategy.ipynb#Rewrite-strategy-to-a-single-function)
#   * [Make a scan of ALL parameters](twp_304_xlp_strategy.ipynb#Make-a-scan-of-ALL-parameters)
#   * [Conclusion](twp_304_xlp_strategy.ipynb#Conclusion)
#   * [Improvements](twp_304_xlp_strategy.ipynb#Improvements)
# * [Pairs trading examples](twp_305_spread_trading_strategy.ipynb#Pairs-trading-examples)
#   * [Get list of XLE components](twp_305_spread_trading_strategy.ipynb#Get-list-of-XLE-components)
#   * [Get the price data](twp_305_spread_trading_strategy.ipynb#Get-the-price-data)
#   * [Visualise dataset](twp_305_spread_trading_strategy.ipynb#Visualise-dataset)
#   * [Build spread and visualise data](twp_305_spread_trading_strategy.ipynb#Build-spread-and-visualise-data)
#   * [Create a trading strategy](twp_305_spread_trading_strategy.ipynb#Create-a-trading-strategy)
#   * [Conclusion](twp_305_spread_trading_strategy.ipynb#Conclusion)
# * [VXX strategy](twp_306_Volatility_trading.ipynb#VXX-strategy)
#   * [Strategy thesis](twp_306_Volatility_trading.ipynb#Strategy-thesis)
#   * [Get the data](twp_306_Volatility_trading.ipynb#Get-the-data)
#   * [Get data from CBOE](twp_306_Volatility_trading.ipynb#Get-data-from-CBOE)
#   * [Research relationship VIX-VIX3M](twp_306_Volatility_trading.ipynb#Research-relationship-VIX-VIX3M)
#   * [More precise simulation](twp_306_Volatility_trading.ipynb#More-precise-simulation)
# * [Leveraged ETF backtest YTD](twp_307_leveraged_etfs_ytd.ipynb#Leveraged-ETF-backtest-YTD)
#   * [Create pairs](twp_307_leveraged_etfs_ytd.ipynb#Create-pairs)
# * [Nearest neighbors strategy](twp_308_trading_VXX_with_nearest_neighbors.ipynb#Nearest-neighbors-strategy)
#   * [Strategy thesis](twp_308_trading_VXX_with_nearest_neighbors.ipynb#Strategy-thesis)
#   * [Prepare data](twp_308_trading_VXX_with_nearest_neighbors.ipynb#Prepare-data)
#   * [Create trader class](twp_308_trading_VXX_with_nearest_neighbors.ipynb#Create-trader-class)
#   * [Conclusion](twp_308_trading_VXX_with_nearest_neighbors.ipynb#Conclusion)
# * [External references](twp_900_references.ipynb#External-references)

# %% [markdown]
# # Reference
#
# ## Jupyter notebook
#  * [overview](twp_101_development_tools.ipynb#Jupyter-notebook)
#  * [markdown](twp_101_development_tools.ipynb#Getting-around)
#  * [magic commands](twp_101_development_tools.ipynb#Cell-magics)
#
# ## backtesting
#  * [walk forward simulation](twp_302c_backtesting-moving_averages.ipynb#Run-walk-forward-simulation)
#  * [parameter scan](twp_302_moving_averages_strat.ipynb#Make-a-parameter-scan)
#  * [parameter scan](twp_304_xlp_strategy.ipynb#Make-a-scan-of-ALL-parameters)
#  * [walk-forward](twp_304_xlp_strategy.ipynb#Walk-Forward-Optimization)
#
# ## csv files
#  * [reading](twp_202_Reading_csv_files.ipynb#Reading-csv)
#  * [reading with pandas](twp_202_Reading_csv_files.ipynb#The-easy-way)
#  * [parse manually](twp_202_Reading_csv_files.ipynb#The-hard-way)
#  * [writing](twp_202_Reading_csv_files.ipynb#Writing-csv-files)
#
# ## data io
#  * [csv files](twp_202_Reading_csv_files.ipynb#Reading-csv)
#  * [excel files](twp_203_Building_a_stock_database.ipynb#Building-a-stock-price-database)
#  * [hdf5](twp_203_Building_a_stock_database.ipynb#Load-data-from-file)
#
# ## datetime
#  * [to and from strings](twp_201_Day_seasonality.ipynb#Working-with-dates-and-times)
#
# ## getting data
#  * [urlretrieve](twp_102a_working_with_modules.ipynb#Working-with-modules)
#  * [get put/call data from CBOE](twp_202_Reading_csv_files.ipynb#Advanced-example)
#  * [get VIX data from CBOE](twp_306_Volatility_trading.ipynb#Get-data-from-CBOE)
#
# ## modules
#  * [overview](twp_102a_working_with_modules.ipynb#Working-with-modules)
#
# ## pandas
#  * [multiindex](twp_203_Building_a_stock_database.ipynb#Multi-index)
#
# ## ploting
#  * [matplotlib, static](twp_103_plotting.ipynb#Static-plots)
#
# ## plotting
#  * [matplotlib, interactive](twp_103_plotting.ipynb#Visualization-with-matplotlib)
#  * [matplotlib figures](twp_103_plotting.ipynb#Creating-figures)
#  * [pandas](twp_103_plotting.ipynb#Plotting-with-Pandas)
#  * [heatmap](twp_304_xlp_strategy.ipynb#Make-a-scan-of-ALL-parameters)
